# %%
from statistics import NormalDist

import pandas as pd

def confidence_interval(data, confidence=0.95):
  dist = NormalDist.from_samples(data)
  z = NormalDist().inv_cdf((1 + confidence) / 2.)
  h = dist.stdev * z / ((len(data) - 1) ** .5)
  return dist.mean - h, dist.mean + h


df = pd.read_csv("data/d2.csv")
mean_confidence_interval(df["receiver_tp_difference"])
# Out:
# (0.12262685355191455, 0.11865535842978371, 0.12659834867404537)

# %%
import numpy as np
import scipy.stats

import pandas as pd
def mean_confidence_interval(data, confidence=0.95):
    a = 1.0 * np.array(data)
    n = len(a)
    m, se = np.mean(a), scipy.stats.sem(a)
    h = se * scipy.stats.t.ppf((1 + confidence) / 2., n-1)
    return m, m-h, m+h

df = pd.read_csv("data/d.csv")
mean_confidence_interval(df["receiver_tp_difference"])
# Out:
# (0.11886744835478263, 0.11427060797946022, 0.12346428873010505)

# %%
# import libraries 
import numpy as np 
import seaborn as sns 
import matplotlib.pyplot as plt 
import pandas as pd
# create random data 
np.random.seed(0) 
df = pd.read_csv("data/d.csv")

# create regression plot 
fig, ax = plt.subplots()
fig.set_size_inches(22.5, 12.5)
ax = sns.regplot(df,y="receiver_tp_difference" , x="time"  )
