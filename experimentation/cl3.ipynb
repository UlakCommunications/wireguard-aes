# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Random numbers for plotting

df = pd.read_csv("data/d.csv")

# Manual binning to retain control
# binwidth = 4 / 10
# x_bins = np.arange(binwidth/2 - 2, 2, binwidth)
sns.regplot(x=df["time"], y=df["receiver_tp_difference"],  fit_reg=None)
# Out:
# <Axes: xlabel='time', ylabel='receiver_tp_difference'>

# %%
ax = plt.gca()
lower = [line.get_ydata().min() for line in ax.lines]
upper = [line.get_ydata().max() for line in ax.lines]
len(lower)
len(upper)
# Out:
# 0

# %%
plt.scatter(df["time"], lower, marker='x', color='C3', zorder=3)

plt.scatter(df["time"], lower, marker='x', color='C3', zorder=3)
plt.scatter(df["receiver_tp_difference"], upper, marker='x', color='C3', zorder=3)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/fatihyuce/work/projects/tmp/wireguard-mayaos/ci/tests/cl3.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell:/home/fatihyuce/work/projects/tmp/wireguard-mayaos/ci/tests/cl3.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> plt.scatter(df["time"], lower, marker='x', color='C3', zorder=3)
#       <a href='vscode-notebook-cell:/home/fatihyuce/work/projects/tmp/wireguard-mayaos/ci/tests/cl3.ipynb#W6sZmlsZQ%3D%3D?line=2'>3</a> plt.scatter(df["time"], lower, marker='x', color='C3', zorder=3)
#       <a href='vscode-notebook-cell:/home/fatihyuce/work/projects/tmp/wireguard-mayaos/ci/tests/cl3.ipynb#W6sZmlsZQ%3D%3D?line=3'>4</a> plt.scatter(df["receiver_tp_difference"], upper, marker='x', color='C3', zorder=3)
#
# ...

# %%
means = ax.collections[0].get_offsets()[:, 1]

# %%
plt.scatter(x_bins, means, color='C1', marker='x', zorder=3)
